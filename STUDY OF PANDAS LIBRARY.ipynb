# %% [markdown]
# #EXPERIMENT 9
# #STUDY OF PANDAS LIBRARY
# # DARSH JAIN
# #PRN: 25070123037
# # ENTC BATCH A2

# %%
import pandas as pd
s= pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Create Dataframe
data={
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df= pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
#Find the structure of the Dataframe
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
#Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check Data types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access individuals columns
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
(df['Marks'])
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
#Access Specific Row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
#Add a new column
df["Grade"]= ["First Class","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#Update data in dataframe
#Change marks of students A to 88
df.loc[0,"Marks"]=88
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#Delete a colum
df.drop("Grade",axis=1, inplace= True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
#Perform Basic Stastistical Analysis
mean1=df["Marks"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
# minimum
min1=df["Marks"].min()
min1
# Out:
# 78

# %%
#maximum
max1=df["Marks"].max()
max1
# Out:
# 90

# %%
#Apply Condition (Filtering)
#Display students scoring marks more than 80.
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
